# %%
# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.collections as matcoll
from scipy import stats

# %%
def createDirectory(dir:str):
    if not os.path.exists(dir):
        os.makedirs(dir)

# %%
def getData(input_file):
    with open(input_file) as f:
        lines = f.readlines()
        x_values = [[float(d) for d in line.split(", ")] for line in lines]
    grain = [f'{int(r[0])}' for r in x_values]
    texture_index = [r[1] for r in x_values]
    entropy = [r[2] for r in x_values]
    return grain, texture_index, entropy

# %%
def plotData(file_path):
    grain, texture_index, entropy = getData(file_path)
    # ======================================== 
    print(grain)
    print(texture_index)
    print(entropy)
    # ========================================
    plt.figure()
    plt.plot(grain, texture_index, marker='.') # , marker='.', linestyle='none'
    # plt.ylabel('Texture Index')
    plt.plot(grain, entropy, marker='.') # , marker='.', linestyle='none'
    # plt.ylabel('Entropy')
    plt.legend(['Texture index','Entropy'])
    plt.xlabel('Grain numbers')
    plt.margins(0.1)

# %%
plotData("./data/8micron_texture_index_entropy.data")
plotData("./data/4micron_texture_index_entropy.data")
# Out:
# ['10', '98', '310', '512', '955', '2160']
# [2.8023, 1.8515, 1.5578, 1.6336, 1.6352, 1.6254]
# [-0.6947, -0.3772, -0.2686, -0.3009, -0.3003, -0.2936]
# ['10', '98', '310']
# [2.6674, 1.9244, 1.6189]
# [-0.6503, -0.3941, -0.2923]
